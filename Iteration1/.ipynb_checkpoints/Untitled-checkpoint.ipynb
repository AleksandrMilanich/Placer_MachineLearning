# %%
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
img = "Example.jpg"
img = cv2.imread(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
blurGauss = cv2.GaussianBlur(gray, (1, 1), 0)
edge = cv2.Canny(blurGauss, 100, 100) 
rect = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
close = cv2.morphologyEx(edge, cv2.MORPH_CLOSE, ker)

# %%
plt.imshow(close)
plt.show()
